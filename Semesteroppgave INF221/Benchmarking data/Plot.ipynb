# %%
import pandas 
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt


plt.rcParams['axes.titlesize'] = 9
plt.rcParams['axes.labelsize'] = 9
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['legend.fontsize'] = 8
plt.rcParams['text.usetex'] = True

def new_figure(height=55):
    "Return figure with width 84mm and given height in mm."

    return plt.figure(figsize=(84/25.4, height/25.4))

# %%
quick_sort = pandas.read_pickle("quick_sort",compression=None)

# %%
merge_sort = pandas.read_pickle("merge_sort", compression=None)

# %%
heap_sort = pandas.read_pickle("heap_sort", compression=None)

# %%
python_sorted = pandas.read_pickle("python_sorted", compression=None)

# %%
numpy_sort = pandas.read_pickle("numpy_sort", compression=None)

# %%
data_quick1 = {'Size':[10, 100, 1000, 10000, 100000], 
       'random_list_int':quick_sort[1][2],
       'random_list_float':quick_sort[1][3], 
       'random_charlist':quick_sort[1][4] } 

data_quick2 = {'Size':[10, 100, 1000],'ascending_list_int': quick_sort[1][0], 'descending_list_int': quick_sort[1][1]}

data_merge = {'Size':[10, 100, 1000, 10000, 100000], 'ascending_list_int':merge_sort[1][0],
       'descending_list_int':merge_sort[1][1], 
       'random_list_int':merge_sort[1][2] ,
       'random_list_float':merge_sort[1][3], 
       'random_charlist':merge_sort[1][4]} 

data_heap = {'Size':[10, 100, 1000, 10000, 100000], 'ascending_list_int':heap_sort[1][0],
       'descending_list_int':heap_sort[1][1], 
       'random_list_int':heap_sort[1][2] ,
       'random_list_float':heap_sort[1][3], 
       'random_charlist':heap_sort[1][4]} 

data_python = {'Size':[10, 100, 1000, 10000, 100000, 1000000, 10000000], 'ascending_list_int':python_sorted[1][0],
       'descending_list_int':python_sorted[1][1], 
       'random_list_int':python_sorted[1][2] ,
       'random_list_float':python_sorted[1][3], 
       'random_charlist':python_sorted[1][4]} 

data_numpy = {'Size':[10, 100, 1000, 10000, 100000, 1000000, 10000000], 'ascending_list_int':numpy_sort[1][0],
       'descending_list_int':numpy_sort[1][1], 
       'random_list_int':numpy_sort[1][2] ,
       'random_list_float':numpy_sort[1][3], 
       'random_charlist':numpy_sort[1][4]}

# %%
df_quick1 = pd.DataFrame(data_quick1) 

df_quick2 = pd.DataFrame(data_quick2) 

df_merge = pd.DataFrame(data_merge)

df_heap = pd.DataFrame(data_heap)

df_python = pd.DataFrame(data_python)

df_numpy = pd.DataFrame(data_numpy)

# %%
fig = new_figure()
ax = fig.add_subplot(1, 1, 1)


ax = sns.lineplot(x = 'Size', y = 'ascending_list_int', data=df_quick2, label = "Ouicksort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'ascending_list_int', data=df_merge, label = "Merge sort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'ascending_list_int', data=df_heap, label = "Heap sort", marker = 'o' )
ax = sns.lineplot(x = 'Size', y = 'ascending_list_int', data=df_python, label = "Python sorted", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'ascending_list_int', data=df_numpy, label = "Numpy sort", marker = 'o')



ax.set_xscale('log')
ax.set_yscale('log')
y = plt.ylabel('Benchmark Time (s)')
x = plt.xlabel('Testdata size')
y = plt.title('Testdata: Ascending List Int')

ax.legend()
fig.savefig('ascending_list_int_plot.pdf', bbox_inches='tight')

# %%
fig = new_figure()
ax = fig.add_subplot(1, 1, 1)

ax = sns.lineplot(x = 'Size', y = 'descending_list_int', data=df_quick2, label = "Ouicksort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'descending_list_int', data=df_merge, label = "Merge sort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'descending_list_int', data=df_heap, label = "Heap sort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'descending_list_int', data=df_python, label = "Python sorted", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'descending_list_int', data=df_numpy, label = "Numpy sort", marker = 'o')

#x = plt.axis(xmin=0, xmax=1000, ymin=0, ymax=0.500)
ax.set_xscale('log')
ax.set_yscale('log')
y = plt.ylabel('Benchmark Time (s)')
x = plt.xlabel('Testdata size')
y = plt.title('Testdata: Descending List Int')

ax.legend()
fig.savefig('descending_list_int_plot.pdf', bbox_inches='tight')

# %%
fig = new_figure()
ax = fig.add_subplot(1, 1, 1)

ax = sns.lineplot(x = 'Size', y = 'random_list_int', data=df_quick1, label = "Ouicksort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'random_list_int', data=df_merge, label = "Merge sort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'random_list_int', data=df_heap, label = "Heap sort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'random_list_int', data=df_python, label = "Python sorted", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'random_list_int', data=df_numpy, label = "Numpy sort", marker = 'o')

ax.set_xscale('log')
ax.set_yscale('log')
y = plt.ylabel('Benchmark Time (s)')
x = plt.xlabel('Testdata size')
y = plt.title('Testdata: Random List Int')

ax.legend()
fig.savefig('random_list_int_plot.pdf', bbox_inches='tight')

# %%
fig = new_figure()
ax = fig.add_subplot(1, 1, 1)
ax = sns.lineplot(x = 'Size', y = 'random_list_float', data=df_quick1, label = "Ouicksort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'random_list_float', data=df_merge, label = "Merge sort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'random_list_float', data=df_heap, label = "Heap sort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'random_list_float', data=df_python, label = "Python sorted", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'random_list_float', data=df_numpy, label = "Numpy sort", marker = 'o')

ax.set_xscale('log')
ax.set_yscale('log')
y = plt.ylabel('Benchmark Time (s)')
x = plt.xlabel('Testdata size')
y = plt.title('Testdata: Random List Float')
ax.legend()
fig.savefig('random_list_float_plot.pdf', bbox_inches='tight')

# %%
fig = new_figure()
ax = fig.add_subplot(1, 1, 1)
ax = sns.lineplot(x = 'Size', y = 'random_charlist', data=df_quick1, label = "Ouicksort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'random_charlist', data=df_merge, label = "Merge sort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'random_charlist', data=df_heap, label = "Heap sort", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'random_charlist', data=df_python, label = "Python sorted", marker = 'o')
ax = sns.lineplot(x = 'Size', y = 'random_charlist', data=df_numpy, label = "Numpy sort", marker = 'o')

ax.set_xscale('log')
ax.set_yscale('log')
y = plt.ylabel('Benchmark Time (s)')
x = plt.xlabel('Testdata size')
y = plt.title('Testdata: Random List Charlist')
ax.legend()
fig.savefig('random_charlist_plot.pdf', bbox_inches='tight')

# %%
df_heap
# Out:
#      Size  ascending_list_int  descending_list_int  random_list_int  \
# 0      10            0.000032             0.000027         0.000032
# 1     100            0.000591             0.000505         0.000561
# 2    1000            0.008896             0.007849         0.008317
# 3   10000            0.122365             0.111884         0.123726
# 4  100000            1.564546             1.453860         1.699788
#
#    random_list_float  random_charlist
# 0           0.000031         0.000029
# 1           0.000510         0.000521
# 2           0.007947         0.008322
# 3           0.111805         0.108955
# 4           1.517157         1.474223

# %%
df_merge
# Out:
#      Size  ascending_list_int  descending_list_int  random_list_int  \
# 0      10            0.000031             0.000032         0.000031
# 1     100            0.000442             0.000447         0.000481
# 2    1000            0.006020             0.005958         0.006776
# 3   10000            0.089463             0.090497         0.097865
# 4  100000            2.652188             2.661839         2.920413
#
#    random_list_float  random_charlist
# 0           0.000032         0.000032
# 1           0.000511         0.000488
# 2           0.006815         0.006854
# 3           0.099463         0.098855
# 4           2.966315         2.748477

# %%
df_quick
# Out:
#      Size  ascending_list_int  descending_list_int  random_list_int  \
# 0      10            0.000030             0.000025         0.000026
# 1     100            0.001861             0.001207         0.000256
# 2    1000            0.171035             0.115719         0.003962
# 3   10000            0.000000             0.000000         0.054825
# 4  100000            0.000000             0.000000         0.692020
#
#    random_list_float  random_charlist
# 0           0.000022         0.000020
# 1           0.000340         0.000328
# 2           0.003942         0.011394
# 3           0.057153         0.740068
# 4           0.706487        72.533960

# %%
df_python
# Out:
#        Size  ascending_list_int  descending_list_int  random_list_int  \
# 0        10        9.862273e-07         9.224728e-07         0.000001
# 1       100        2.855889e-06         2.487179e-06         0.000007
# 2      1000        1.600187e-05         1.809069e-05         0.000133
# 3     10000        1.585006e-04         1.943484e-04         0.001881
# 4    100000        3.405358e-03         3.255895e-03         0.026922
# 5   1000000        3.635347e-02         3.740138e-02         0.435820
# 6  10000000        4.608474e-01         4.892139e-01         6.078180
#
#    random_list_float  random_charlist
# 0           0.000001         0.000001
# 1           0.000007         0.000009
# 2           0.000113         0.000131
# 3           0.001642         0.001606
# 4           0.025269         0.015091
# 5           0.356734         0.172809
# 6           5.019687         1.593080

# %%
df_numpy
# Out:
#        Size  ascending_list_int  descending_list_int  random_list_int  \
# 0        10            0.000010             0.000010         0.000011
# 1       100            0.000020             0.000020         0.000020
# 2      1000            0.000111             0.000135         0.000162
# 3     10000            0.001100             0.001178         0.001570
# 4    100000            0.011401             0.012267         0.018684
# 5   1000000            0.130086             0.137472         0.201150
# 6  10000000            1.313866             1.419500         2.155744
#
#    random_list_float  random_charlist
# 0           0.000009         0.000010
# 1           0.000016         0.000021
# 2           0.000110         0.000150
# 3           0.001283         0.001605
# 4           0.015248         0.016870
# 5           0.178262         0.189407
# 6           1.939330         2.275960
